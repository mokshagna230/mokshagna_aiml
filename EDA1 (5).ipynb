# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data_clean.csv")
print(data)
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
print(type(data))
print(data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (158, 10)

# %%
data.shape
# Out:
# (158, 10)

# %%
data.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
print(type(data))
print(data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (158, 10)

# %%
data1 = data.drop(['Unnamed: 0',"Temp C"],axis =1)
data1
# Out:
#      Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     5    1  2010    67       S
# 1     36.0    118.0   8.0     5    2  2010    72       C
# 2     12.0    149.0  12.6     5    3  2010    74      PS
# 3     18.0    313.0  11.5     5    4  2010    62       S
# 4      NaN      NaN  14.3     5    5  2010    56       S
# ..     ...      ...   ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     5    1  2010    67       C
# 154   30.0    193.0   6.9     9   26  2010    70      PS
# 155    NaN    145.0  13.2     9   27  2010    77       S
# 156   14.0    191.0  14.3     9   28  2010    75       S
# 157   18.0    131.0   8.0     9   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Month    158 non-null    object
#  4   Day      158 non-null    int64
#  5   Year     158 non-null    int64
#  6   Temp     158 non-null    int64
#  7   Weather  155 non-null    object
# dtypes: float64(3), int64(3), object(2)
# memory usage: 10.0+ KB

# %%
data1['Month']=pd.to_numeric(data['Month'],errors='coerce')
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Month    157 non-null    float64
#  4   Day      158 non-null    int64
#  5   Year     158 non-null    int64
#  6   Temp     158 non-null    int64
#  7   Weather  155 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 10.0+ KB

# %%
data1[data1.duplicated()]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 156   14.0    191.0  14.3    9.0   28  2010    75       S

# %%
data1[data1.duplicated(keep = False)]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 150   14.0    191.0  14.3    9.0   28  2010    75       S
# 156   14.0    191.0  14.3    9.0   28  2010    75       S

# %%
data1.rename({'Solar.R': 'Solar'},axis=1, inplace = True)
data1
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4    5.0    1  2010    67       S
# 1     36.0  118.0   8.0    5.0    2  2010    72       C
# 2     12.0  149.0  12.6    5.0    3  2010    74      PS
# 3     18.0  313.0  11.5    5.0    4  2010    62       S
# 4      NaN    NaN  14.3    5.0    5  2010    56       S
# ..     ...    ...   ...    ...  ...   ...   ...     ...
# 153   41.0  190.0   7.4    5.0    1  2010    67       C
# 154   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155    NaN  145.0  13.2    9.0   27  2010    77       S
# 156   14.0  191.0  14.3    9.0   28  2010    75       S
# 157   18.0  131.0   8.0    9.0   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
data1.isnull().sum()
# Out:
# Ozone      38
# Solar       7
# Wind        0
# Month       1
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
cols = data1.columns
colours = ['black', 'yellow']
sns.heatmap(data1[cols].isnull(),cmap=sns.color_palette(colours),cbar = True)
# Out:
# <Axes: >

# %%
median_ozone = data1["Ozone"].median()
mean_ozone = data1["Ozone"].mean()
print("Median of Ozone: ",median_ozone)
print("Mean of Ozone: ",mean_ozone)
# Out:
# Median of Ozone:  30.5
# Mean of Ozone:  41.583333333333336

# %%
data1['Ozone'] = data1['Ozone'].fillna(median_ozone)
data1.isnull().sum()
# Out:
# Ozone      0
# Solar      7
# Wind       0
# Month      1
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %%
median_solar = data1["Solar"].median()
mean_solar = data1["Solar"].mean()
print("Median of Solar: ",median_solar)
print("Mean of Solar: ",mean_solar)
# Out:
# Median of Solar:  197.0
# Mean of Solar:  185.40397350993376

# %%
data1['Solar'] = data1['Solar'].fillna(median_solar)
data1.isnull().sum()
# Out:
# Ozone      0
# Solar      0
# Wind       0
# Month      1
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %%
print(data1["Weather"].value_counts())
mode_weather = data1["Weather"].mode()[0]
print(mode_weather)
# Out:
# Weather
# S     59
# C     49
# PS    47
# Name: count, dtype: int64
# S

# %%
data1["Weather"] = data1["Weather"].fillna(mode_weather)
data1.isnull().sum()
# Out:
# Ozone      0
# Solar      0
# Wind       0
# Month      1
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
print(data1["Month"].value_counts())
mode_month = data1["Month"].mode()[0]
print(mode_month)
# Out:
# Month
# 9.0    34
# 5.0    31
# 7.0    31
# 8.0    31
# 6.0    30
# Name: count, dtype: int64
# 9.0

# %%
data1['Month'] = data1['Month'].fillna(median_solar)
data1.isnull().sum()
# Out:
# Ozone      0
# Solar      0
# Wind       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
data1.reset_index(drop=True)
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4    5.0    1  2010    67       S
# 1     36.0  118.0   8.0    5.0    2  2010    72       C
# 2     12.0  149.0  12.6    5.0    3  2010    74      PS
# 3     18.0  313.0  11.5    5.0    4  2010    62       S
# 4     30.5  197.0  14.3    5.0    5  2010    56       S
# ..     ...    ...   ...    ...  ...   ...   ...     ...
# 153   41.0  190.0   7.4    5.0    1  2010    67       C
# 154   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155   30.5  145.0  13.2    9.0   27  2010    77       S
# 156   14.0  191.0  14.3    9.0   28  2010    75       S
# 157   18.0  131.0   8.0    9.0   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
fig, axes=plt.subplots(2, 1, figsize=(8, 6), gridspec_kw={'height_ratios':[1, 3]})
sns.boxplot(data=data1["Ozone"], ax=axes[0],color='skyblue',width=0.5, orient='h')
axes[0].set_title("Boxplot")
axes[0].set_xlabel("Ozone Levels")
sns.histplot(data1["Ozone"], kde=True, ax=axes[1],color='purple',bins=30)
axes[1].set_title("Histogram with KDE")
axes[1].set_xlabel("Ozone Levels")
axes[1].set_ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
sns.violinplot(data=data1["Ozone"], color='lightgreen')
plt.title("violin plot")
# Out:
# Text(0.5, 1.0, 'violin plot')

# %%
plt.figure(figsize=(6,2))
boxplot_data = plt.boxplot(data1["Ozone"], vert=False)
[item.get_xdata() for item in boxplot_data['fliers']]
# Out:
# [array([115., 135.,  97.,  97.,  85., 108.,  82., 122.,  89., 110., 168.,
#         118.,  84.,  85.,  96.,  91.])]

# %%
data1["Ozone"].describe()
# Out:
# count    158.000000
# mean      38.917722
# std       28.794730
# min        1.000000
# 25%       21.000000
# 50%       30.500000
# 75%       45.000000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
mu = data1["Ozone"].describe()[1]
sigma = data1["Ozone"].describe()[2]

for x in data1["Ozone"]:
    if ((x < (mu - 3*sigma)) or (x > (mu + 3*sigma))):
        print(x)
# Out:
# 135.0
# 168.0
# C:\Users\Golla\AppData\Local\Temp\ipykernel_30844\3121128980.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mu = data1["Ozone"].describe()[1]
# C:\Users\Golla\AppData\Local\Temp\ipykernel_30844\3121128980.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sigma = data1["Ozone"].describe()[2]

# %%
import scipy.stats as stats
plt.figure(figsize=(8,6))
stats.probplot(data1["Ozone"], dist="norm", plot=plt)
plt.title("Q-Q plot for Outlier Detection", fontsize=14)
plt.xlabel("Theroretical Quantiles",fontsize=12)
# Out:
# Text(0.5, 0, 'Theroretical Quantiles')

# %%
sns.violinplot(data=data1["Ozone"], color='lightgreen')
plt.title("violin plot")
plt.show()

# %%
sns.swarmplot(data=data1, x = "Weather", y = "Ozone",color="orange",palette="Set2", size=6)
# Out:
# C:\Users\Golla\AppData\Local\Temp\ipykernel_30844\1222012946.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data=data1, x = "Weather", y = "Ozone",color="orange",palette="Set2", size=6)
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
sns.stripplot(data=data1, x = "Weather", y = "Ozone",color="orange",palette="Set1", size=6, jitter = True)
# Out:
# C:\Users\Golla\AppData\Local\Temp\ipykernel_30844\2160529860.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=data1, x = "Weather", y = "Ozone",color="orange",palette="Set1", size=6, jitter = True)
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
sns.kdeplot(data=data1["Ozone"], fill=True, color="blue")
sns.rugplot(data=data1["Ozone"], color="black")
# Out:
# <Axes: xlabel='Ozone', ylabel='Density'>

# %%
#Category wise boxplot for ozone
sns.boxplot(data=data1,x="Weather",y="Ozone")
# Out:
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
plt.scatter(data1["Wind"], data1["Temp"])

# %%
data1["Wind"].corr(data1["Temp"])
# Out:
# -0.441246717631239

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    158 non-null    float64
#  1   Solar    158 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Month    158 non-null    float64
#  4   Day      158 non-null    int64
#  5   Year     158 non-null    int64
#  6   Temp     158 non-null    int64
#  7   Weather  158 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 10.0+ KB

# %%
data1_numeric = data1.iloc[:,[0,1,2,5]]
data1_numeric
# Out:
#      Ozone  Solar  Wind  Year
# 0     41.0  190.0   7.4  2010
# 1     36.0  118.0   8.0  2010
# 2     12.0  149.0  12.6  2010
# 3     18.0  313.0  11.5  2010
# 4     30.5  197.0  14.3  2010
# ..     ...    ...   ...   ...
# 153   41.0  190.0   7.4  2010
# 154   30.0  193.0   6.9  2010
# 155   30.5  145.0  13.2  2010
# 156   14.0  191.0  14.3  2010
# 157   18.0  131.0   8.0  2010
#
# [158 rows x 4 columns]

# %%
data1_numeric.corr()
# Out:
#           Ozone     Solar      Wind  Year
# Ozone  1.000000  0.296048 -0.526616   NaN
# Solar  0.296048  1.000000 -0.056697   NaN
# Wind  -0.526616 -0.056697  1.000000   NaN
# Year        NaN       NaN       NaN   NaN

# %% [markdown]
# observations
# .the highest correlation strength is observed between ozone and temperature(0.597087)
# .the next higher correlation strength is observed between ozone and wind(-0.523738)
# .the next higher correlation strength is observed between wind and temperature(-0.441223)
# the last correlation strength is observed between solar and wind(-0.03312)

# %%
sns.pairplot(data1_numeric)

# %%
data2=pd.get_dummies(data1,columns=['Month','Weather'])
data2
# Out:
#      Ozone  Solar  Wind  Day  Year  Temp  Month_5.0  Month_6.0  Month_7.0  \
# 0     41.0  190.0   7.4    1  2010    67       True      False      False
# 1     36.0  118.0   8.0    2  2010    72       True      False      False
# 2     12.0  149.0  12.6    3  2010    74       True      False      False
# 3     18.0  313.0  11.5    4  2010    62       True      False      False
# 4     30.5  197.0  14.3    5  2010    56       True      False      False
# ..     ...    ...   ...  ...   ...   ...        ...        ...        ...
# 153   41.0  190.0   7.4    1  2010    67       True      False      False
# 154   30.0  193.0   6.9   26  2010    70      False      False      False
# 155   30.5  145.0  13.2   27  2010    77      False      False      False
# 156   14.0  191.0  14.3   28  2010    75      False      False      False
# 157   18.0  131.0   8.0   29  2010    76      False      False      False
#
#      Month_8.0  Month_9.0  Month_197.0  Weather_C  Weather_PS  Weather_S
# 0        False      False        False      False       False       True
# 1        False      False        False       True       False      False
# 2        False      False        False      False        True      False
# 3        False      False        False      False       False       True
# 4        False      False        False      False       False       True
# ..         ...        ...          ...        ...         ...        ...
# 153      False      False        False       True       False      False
# 154      False       True        False      False        True      False
# 155      False       True        False      False       False       True
# 156      False       True        False      False       False       True
# 157      False       True        False       True       False      False
#
# [158 rows x 15 columns]

# %% [markdown]
# Normalization of the data

# %%
data1_numeric.values
# Out:
# array([[4.10e+01, 1.90e+02, 7.40e+00, 2.01e+03],
#        [3.60e+01, 1.18e+02, 8.00e+00, 2.01e+03],
#        [1.20e+01, 1.49e+02, 1.26e+01, 2.01e+03],
#        [1.80e+01, 3.13e+02, 1.15e+01, 2.01e+03],
#        [3.05e+01, 1.97e+02, 1.43e+01, 2.01e+03],
#        [2.80e+01, 1.97e+02, 1.49e+01, 2.01e+03],
#        [2.30e+01, 2.99e+02, 8.60e+00, 2.01e+03],
#        [1.90e+01, 9.90e+01, 1.38e+01, 2.01e+03],
#        [8.00e+00, 1.90e+01, 2.01e+01, 2.01e+03],
#        [3.05e+01, 1.94e+02, 8.60e+00, 2.01e+03],
#        [7.00e+00, 1.97e+02, 6.90e+00, 2.01e+03],
#        [1.60e+01, 2.56e+02, 9.70e+00, 2.01e+03],
#        [1.10e+01, 2.90e+02, 9.20e+00, 2.01e+03],
#        [1.40e+01, 2.74e+02, 1.09e+01, 2.01e+03],
#        [1.80e+01, 6.50e+01, 1.32e+01, 2.01e+03],
#        [1.40e+01, 3.34e+02, 1.15e+01, 2.01e+03],
#        [3.40e+01, 3.07e+02, 1.20e+01, 2.01e+03],
#        [6.00e+00, 7.80e+01, 1.84e+01, 2.01e+03],
#        [3.00e+01, 3.22e+02, 1.15e+01, 2.01e+03],
#        [1.10e+01, 4.40e+01, 9.70e+00, 2.01e+03],
#        [1.00e+00, 8.00e+00, 9.70e+00, 2.01e+03],
#        [1.10e+01, 3.20e+02, 1.66e+01, 2.01e+03],
#        [4.00e+00, 2.50e+01, 9.70e+00, 2.01e+03],
#        [3.20e+01, 9.20e+01, 1.20e+01, 2.01e+03],
#        [3.05e+01, 6.60e+01, 1.66e+01, 2.01e+03],
#        [3.05e+01, 2.66e+02, 1.49e+01, 2.01e+03],
#        [3.05e+01, 1.97e+02, 8.00e+00, 2.01e+03],
#        [2.30e+01, 1.30e+01, 1.20e+01, 2.01e+03],
#        [4.50e+01, 2.52e+02, 1.49e+01, 2.01e+03],
#        [1.15e+02, 2.23e+02, 5.70e+00, 2.01e+03],
#        [3.70e+01, 2.79e+02, 7.40e+00, 2.01e+03],
#        [3.05e+01, 2.86e+02, 8.60e+00, 2.01e+03],
#        [3.05e+01, 2.87e+02, 9.70e+00, 2.01e+03],
#        [3.05e+01, 2.42e+02, 1.61e+01, 2.01e+03],
#        [3.05e+01, 1.86e+02, 9.20e+00, 2.01e+03],
#        [3.05e+01, 2.20e+02, 8.60e+00, 2.01e+03],
#        [3.05e+01, 2.64e+02, 1.43e+01, 2.01e+03],
#        [2.90e+01, 1.27e+02, 9.70e+00, 2.01e+03],
#        [3.05e+01, 2.73e+02, 6.90e+00, 2.01e+03],
#        [7.10e+01, 2.91e+02, 1.38e+01, 2.01e+03],
#        [3.90e+01, 3.23e+02, 1.15e+01, 2.01e+03],
#        [3.05e+01, 2.59e+02, 1.09e+01, 2.01e+03],
#        [3.05e+01, 2.50e+02, 9.20e+00, 2.01e+03],
#        [2.30e+01, 1.48e+02, 8.00e+00, 2.01e+03],
#        [3.05e+01, 3.32e+02, 1.38e+01, 2.01e+03],
#        [3.05e+01, 3.22e+02, 1.15e+01, 2.01e+03],
#        [2.10e+01, 1.91e+02, 1.49e+01, 2.01e+03],
#        [3.70e+01, 2.84e+02, 2.07e+01, 2.01e+03],
#        [2.00e+01, 3.70e+01, 9.20e+00, 2.01e+03],
#        [1.20e+01, 1.20e+02, 1.15e+01, 2.01e+03],
#        [1.30e+01, 1.37e+02, 1.03e+01, 2.01e+03],
#        [3.05e+01, 1.50e+02, 6.30e+00, 2.01e+03],
#        [3.05e+01, 5.90e+01, 1.70e+00, 2.01e+03],
#        [3.05e+01, 9.10e+01, 4.60e+00, 2.01e+03],
#        [3.05e+01, 2.50e+02, 6.30e+00, 2.01e+03],
#        [3.05e+01, 1.35e+02, 8.00e+00, 2.01e+03],
#        [3.05e+01, 1.27e+02, 8.00e+00, 2.01e+03],
#        [3.05e+01, 4.70e+01, 1.03e+01, 2.01e+03],
#        [3.05e+01, 9.80e+01, 1.15e+01, 2.01e+03],
#        [3.05e+01, 3.10e+01, 1.49e+01, 2.01e+03],
#        [3.05e+01, 1.38e+02, 8.00e+00, 2.01e+03],
#        [1.35e+02, 2.69e+02, 4.10e+00, 2.01e+03],
#        [4.90e+01, 2.48e+02, 9.20e+00, 2.01e+03],
#        [3.20e+01, 2.36e+02, 9.20e+00, 2.01e+03],
#        [3.05e+01, 1.01e+02, 1.09e+01, 2.01e+03],
#        [6.40e+01, 1.75e+02, 4.60e+00, 2.01e+03],
#        [4.00e+01, 3.14e+02, 1.09e+01, 2.01e+03],
#        [7.70e+01, 2.76e+02, 5.10e+00, 2.01e+03],
#        [9.70e+01, 2.67e+02, 6.30e+00, 2.01e+03],
#        [9.70e+01, 2.72e+02, 5.70e+00, 2.01e+03],
#        [8.50e+01, 1.75e+02, 7.40e+00, 2.01e+03],
#        [3.05e+01, 1.39e+02, 8.60e+00, 2.01e+03],
#        [1.00e+01, 2.64e+02, 1.43e+01, 2.01e+03],
#        [2.70e+01, 1.75e+02, 1.49e+01, 2.01e+03],
#        [3.05e+01, 2.91e+02, 1.49e+01, 2.01e+03],
#        [7.00e+00, 4.80e+01, 1.43e+01, 2.01e+03],
#        [4.80e+01, 2.60e+02, 6.90e+00, 2.01e+03],
#        [3.50e+01, 2.74e+02, 1.03e+01, 2.01e+03],
#        [6.10e+01, 2.85e+02, 6.30e+00, 2.01e+03],
#        [7.90e+01, 1.87e+02, 5.10e+00, 2.01e+03],
#        [6.30e+01, 2.20e+02, 1.15e+01, 2.01e+03],
#        [1.60e+01, 7.00e+00, 6.90e+00, 2.01e+03],
#        [3.05e+01, 2.58e+02, 9.70e+00, 2.01e+03],
#        [3.05e+01, 2.95e+02, 1.15e+01, 2.01e+03],
#        [8.00e+01, 2.94e+02, 8.60e+00, 2.01e+03],
#        [1.08e+02, 2.23e+02, 8.00e+00, 2.01e+03],
#        [2.00e+01, 8.10e+01, 8.60e+00, 2.01e+03],
#        [5.20e+01, 8.20e+01, 1.20e+01, 2.01e+03],
#        [8.20e+01, 2.13e+02, 7.40e+00, 2.01e+03],
#        [5.00e+01, 2.75e+02, 7.40e+00, 2.01e+03],
#        [6.40e+01, 2.53e+02, 7.40e+00, 2.01e+03],
#        [5.90e+01, 2.54e+02, 9.20e+00, 2.01e+03],
#        [3.90e+01, 8.30e+01, 6.90e+00, 2.01e+03],
#        [9.00e+00, 2.40e+01, 1.38e+01, 2.01e+03],
#        [1.60e+01, 7.70e+01, 7.40e+00, 2.01e+03],
#        [7.80e+01, 1.97e+02, 6.90e+00, 2.01e+03],
#        [3.50e+01, 1.97e+02, 7.40e+00, 2.01e+03],
#        [6.60e+01, 1.97e+02, 4.60e+00, 2.01e+03],
#        [1.22e+02, 2.55e+02, 4.00e+00, 2.01e+03],
#        [8.90e+01, 2.29e+02, 1.03e+01, 2.01e+03],
#        [1.10e+02, 2.07e+02, 8.00e+00, 2.01e+03],
#        [3.05e+01, 2.22e+02, 8.60e+00, 2.01e+03],
#        [3.05e+01, 1.37e+02, 1.15e+01, 2.01e+03],
#        [4.40e+01, 1.92e+02, 1.15e+01, 2.01e+03],
#        [2.80e+01, 2.73e+02, 1.15e+01, 2.01e+03],
#        [6.50e+01, 1.57e+02, 9.70e+00, 2.01e+03],
#        [3.05e+01, 6.40e+01, 1.15e+01, 2.01e+03],
#        [2.20e+01, 7.10e+01, 1.03e+01, 2.01e+03],
#        [5.90e+01, 5.10e+01, 6.30e+00, 2.01e+03],
#        [2.30e+01, 1.15e+02, 7.40e+00, 2.01e+03],
#        [3.10e+01, 2.44e+02, 1.09e+01, 2.01e+03],
#        [4.40e+01, 1.90e+02, 1.03e+01, 2.01e+03],
#        [2.10e+01, 2.59e+02, 1.55e+01, 2.01e+03],
#        [9.00e+00, 3.60e+01, 1.43e+01, 2.01e+03],
#        [3.05e+01, 2.55e+02, 1.26e+01, 2.01e+03],
#        [4.50e+01, 2.12e+02, 9.70e+00, 2.01e+03],
#        [1.68e+02, 2.38e+02, 3.40e+00, 2.01e+03],
#        [7.30e+01, 2.15e+02, 8.00e+00, 2.01e+03],
#        [3.05e+01, 1.53e+02, 5.70e+00, 2.01e+03],
#        [7.60e+01, 2.03e+02, 9.70e+00, 2.01e+03],
#        [1.18e+02, 2.25e+02, 2.30e+00, 2.01e+03],
#        [8.40e+01, 2.37e+02, 6.30e+00, 2.01e+03],
#        [8.50e+01, 1.88e+02, 6.30e+00, 2.01e+03],
#        [9.60e+01, 1.67e+02, 6.90e+00, 2.01e+03],
#        [7.80e+01, 1.97e+02, 5.10e+00, 2.01e+03],
#        [7.30e+01, 1.83e+02, 2.80e+00, 2.01e+03],
#        [9.10e+01, 1.89e+02, 4.60e+00, 2.01e+03],
#        [4.70e+01, 9.50e+01, 7.40e+00, 2.01e+03],
#        [3.20e+01, 9.20e+01, 1.55e+01, 2.01e+03],
#        [2.00e+01, 2.52e+02, 1.09e+01, 2.01e+03],
#        [2.30e+01, 2.20e+02, 1.03e+01, 2.01e+03],
#        [2.10e+01, 2.30e+02, 1.09e+01, 2.01e+03],
#        [2.40e+01, 2.59e+02, 9.70e+00, 2.01e+03],
#        [4.40e+01, 2.36e+02, 1.49e+01, 2.01e+03],
#        [2.10e+01, 2.59e+02, 1.55e+01, 2.01e+03],
#        [2.80e+01, 2.38e+02, 6.30e+00, 2.01e+03],
#        [9.00e+00, 2.40e+01, 1.09e+01, 2.01e+03],
#        [1.30e+01, 1.12e+02, 1.15e+01, 2.01e+03],
#        [4.60e+01, 2.37e+02, 6.90e+00, 2.01e+03],
#        [1.80e+01, 2.24e+02, 1.38e+01, 2.01e+03],
#        [1.30e+01, 2.70e+01, 1.03e+01, 2.01e+03],
#        [2.40e+01, 2.38e+02, 1.03e+01, 2.01e+03],
#        [1.60e+01, 2.01e+02, 8.00e+00, 2.01e+03],
#        [1.30e+01, 2.38e+02, 1.26e+01, 2.01e+03],
#        [2.30e+01, 1.40e+01, 9.20e+00, 2.01e+03],
#        [3.60e+01, 1.39e+02, 1.03e+01, 2.01e+03],
#        [7.00e+00, 4.90e+01, 1.03e+01, 2.01e+03],
#        [1.40e+01, 2.00e+01, 1.66e+01, 2.01e+03],
#        [3.00e+01, 1.93e+02, 6.90e+00, 2.01e+03],
#        [3.05e+01, 1.45e+02, 1.32e+01, 2.01e+03],
#        [1.40e+01, 1.91e+02, 1.43e+01, 2.01e+03],
#        [1.80e+01, 1.31e+02, 8.00e+00, 2.01e+03],
#        [2.00e+01, 2.23e+02, 1.15e+01, 2.01e+03],
#        [4.10e+01, 1.90e+02, 7.40e+00, 2.01e+03],
#        [3.00e+01, 1.93e+02, 6.90e+00, 2.01e+03],
#        [3.05e+01, 1.45e+02, 1.32e+01, 2.01e+03],
#        [1.40e+01, 1.91e+02, 1.43e+01, 2.01e+03],
#        [1.80e+01, 1.31e+02, 8.00e+00, 2.01e+03]])

# %%
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

array = data1_numeric.values

scaler = MinMaxScaler(feature_range=(0,1))
rescaledX = scaler.fit_transform(array)

set_printoptions(precision=2)
print(rescaledX[0:10,:])
# Out:
# [[0.24 0.56 0.3  0.  ]
#  [0.21 0.34 0.33 0.  ]
#  [0.07 0.43 0.57 0.  ]
#  [0.1  0.94 0.52 0.  ]
#  [0.18 0.58 0.66 0.  ]
#  [0.16 0.58 0.69 0.  ]
#  [0.13 0.89 0.36 0.  ]
#  [0.11 0.28 0.64 0.  ]
#  [0.04 0.04 0.97 0.  ]
#  [0.18 0.57 0.36 0.  ]]
